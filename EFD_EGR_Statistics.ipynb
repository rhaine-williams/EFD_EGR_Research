# %%
# Mounting Google Drive
import os 
from google.colab import drive 
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Importing pandas and numpy
import pandas as pd
import numpy as np 
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# %%
# Reading data
df1 = pd.read_csv('/content/gdrive/MyDrive/EGR_Research_Project_1/EFD_Student_data.csv', encoding='latin-1')
print(df1.head(5))
# Out:
#    Unnamed: 0  Student ID 100-1 DFW 100? 100-2 100-3 105-1 DFW 105? 105-2  \
# 0           0     1182139   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 1           1     1220918   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2           2     1240519   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 3           3     1676530   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 4           4     2103593   NaN      NaN   NaN   NaN   NaN      NaN   NaN
#
#   120-1  ... 202-3 204-1 DFW 204? 204-2 204-3 Age  Gender        Ethnicity  \
# 0   NaN  ...   NaN   NaN      NaN   NaN   NaN  40    Male            Asian
# 1   NaN  ...   NaN   NaN      NaN   NaN   NaN  36  Female            White
# 2   NaN  ...   NaN     A       NO   NaN   NaN  36  Female            White
# 3   NaN  ...   NaN   NaN      NaN   NaN   NaN  29    Male            White
# 4   NaN  ...   NaN   NaN      NaN   NaN   NaN  29    Male  Hispanic/Latino
#
#   Military Status International
# 0        Civilian             N
# ...

# %%
df1
# Out:
#       Unnamed: 0  Student ID 100-1 DFW 100? 100-2 100-3 105-1 DFW 105? 105-2  \
# 0              0     1182139   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 1              1     1220918   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2              2     1240519   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 3              3     1676530   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 4              4     2103593   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# ...          ...         ...   ...      ...   ...   ...   ...      ...   ...
# 2312        2312     2612639   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2313        2313     2613310   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2314        2314     2613312   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2315        2315     2614742     A       NO   NaN   NaN   NaN      NaN   NaN
# 2316        2316     2616097   NaN      NaN   NaN   NaN   NaN      NaN   NaN
#
# ...

# %% [markdown]
# Percentage of students who never took EGR 120:
#
# Main assumptions: Received transfer credit, switched majors, dropped out

# %%
EFD_nan_120 = df1[df1[['120-1']].isna().all(axis=1)]
EFD_nan_120
# Out:
#       Unnamed: 0  Student ID 100-1 DFW 100? 100-2 100-3 105-1 DFW 105? 105-2  \
# 0              0     1182139   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 1              1     1220918   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2              2     1240519   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 3              3     1676530   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 4              4     2103593   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# ...          ...         ...   ...      ...   ...   ...   ...      ...   ...
# 2303        2303     2611084     A       NO   NaN   NaN   NaN      NaN   NaN
# 2305        2305     2611456     B       NO   NaN   NaN   NaN      NaN   NaN
# 2310        2310     2612149     B       NO   NaN   NaN   NaN      NaN   NaN
# 2312        2312     2612639   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2315        2315     2614742     A       NO   NaN   NaN   NaN      NaN   NaN
#
# ...

# %%
EFD_nan_100 = df1[df1[['100-1']].isna().all(axis=1)]
EFD_nan_100
# Out:
#       Unnamed: 0  Student ID 100-1 DFW 100? 100-2 100-3 105-1 DFW 105? 105-2  \
# 0              0     1182139   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 1              1     1220918   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2              2     1240519   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 3              3     1676530   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 4              4     2103593   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# ...          ...         ...   ...      ...   ...   ...   ...      ...   ...
# 2311        2311     2612309   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2312        2312     2612639   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2313        2313     2613310   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2314        2314     2613312   NaN      NaN   NaN   NaN   NaN      NaN   NaN
# 2316        2316     2616097   NaN      NaN   NaN   NaN   NaN      NaN   NaN
#
# ...

# %%
EFD_num_nan_120 = len(EFD_nan_120)
EFD_num_nan_120
# Out:
# 940

# %%
percent_EFD_nan_120 = (EFD_num_nan_120/2317)*100
percent_EFD_nan_120
# Out:
# 40.56970220112214

# %%
df1.drop(df1.columns.difference(['Student ID','100-1','120-1']), 1, inplace=True)
df1
# Out:
# <ipython-input-9-0a986ea601a1>:1: FutureWarning: In a future version of pandas all arguments of DataFrame.drop except for the argument 'labels' will be keyword-only.
#   df1.drop(df1.columns.difference(['Student ID','100-1','120-1']), 1, inplace=True)
#       Student ID 100-1 120-1
# 0        1182139   NaN   NaN
# 1        1220918   NaN   NaN
# 2        1240519   NaN   NaN
# 3        1676530   NaN   NaN
# 4        2103593   NaN   NaN
# ...          ...   ...   ...
# 2312     2612639   NaN   NaN
# 2313     2613310   NaN     A
# 2314     2613312   NaN     B
# 2315     2614742     A   NaN
# 2316     2616097   NaN     B
#
# [2317 rows x 3 columns]

# %% [markdown]
# **Dropping students who did not do EGR 100 OR EGR 120 from dataset**

# %%
df1 = df1.dropna(subset=['100-1','120-1'], how='all')
df1
# Out:
#       Student ID 100-1 120-1
# 8        2306884   NaN     B
# 10       2335068   NaN     A
# 11       2340351   NaN     A
# 12       2343598   NaN     C
# 14       2373631   NaN     A
# ...          ...   ...   ...
# 2311     2612309   NaN     A
# 2313     2613310   NaN     A
# 2314     2613312   NaN     B
# 2315     2614742     A   NaN
# 2316     2616097   NaN     B
#
# [1566 rows x 3 columns]

# %% [markdown]
# The number of students who took either EGR 100, EGR 120 or both:

# %%
total_100_120 = len(df1)
total_100_120
# Out:
# 1566

# %% [markdown]
# The students who never took 120 and their grades for EGR 100:

# %%
nan_120 = df1[df1[['120-1']].isna().all(axis=1)]
nan_120
# Out:
#       Student ID 100-1 120-1
# 89       2480782     A   NaN
# 137      2496781     F   NaN
# 151      2498011     B   NaN
# 282      2512364     A   NaN
# 304      2516201     C   NaN
# ...          ...   ...   ...
# 2301     2610765     D   NaN
# 2303     2611084     A   NaN
# 2305     2611456     B   NaN
# 2310     2612149     B   NaN
# 2315     2614742     A   NaN
#
# [189 rows x 3 columns]

# %%
nan_120 = nan_120.sort_values('100-1', ascending = True)
nan_120
# Out:
#       Student ID 100-1 120-1
# 89       2480782     A   NaN
# 2005     2597608     A   NaN
# 1993     2597229     A   NaN
# 1991     2597104     A   NaN
# 1977     2597010     A   NaN
# ...          ...   ...   ...
# 1116     2566560     W   NaN
# 2076     2598817     W   NaN
# 1159     2567475     W   NaN
# 1467     2573980     W   NaN
# 1613     2578275     W   NaN
#
# [189 rows x 3 columns]

# %%
num_nan_120 = len(nan_120)
num_nan_120
# Out:
# 189

# %% [markdown]
# Percentage of EGR 100 students who never took 120:

# %%
percent_nan_120 = (num_nan_120/total_100_120)*100
percent_nan_120
# Out:
# 12.068965517241379

# %% [markdown]
# Distribution of grades for students who never took 100:
# (Try a histogram)

# %%
ax = sns.histplot(data=nan_120, x="100-1", stat='count', kde=False)
ax.bar_label(ax.containers[0])
# Out:
# [Text(0, 0, '')]

# %%
ax = sns.histplot(data=nan_120, x="100-1", stat='percent', kde=False)
ax.bar_label(ax.containers[0], fmt='%.2f%%')
# Out:
# [Text(0, 0, '')]

# %%
ax = sns.histplot(data=nan_120, x="100-1", kde=False, stat='density', label='samples')

# calculate the pdf
x0, x1 = ax.get_xlim()  # extract the endpoints for the x-axis
x_pdf = np.linspace(x0, x1, 100)
y_pdf = stats.norm.pdf(x_pdf)

ax.plot(x_pdf, y_pdf, 'r', lw=2, label='pdf')                                                   
ax.legend()

# %% [markdown]
# Dropping the students who never took 120 from the entire dataset. This will help to show the relation in grades between who took both classes and who only took 120:

# %%
df1 = df1.dropna(subset=['120-1'], how='all')
df1
# Out:
#       Student ID 100-1 120-1
# 8        2306884   NaN     B
# 10       2335068   NaN     A
# 11       2340351   NaN     A
# 12       2343598   NaN     C
# 14       2373631   NaN     A
# ...          ...   ...   ...
# 2309     2612061   NaN     A
# 2311     2612309   NaN     A
# 2313     2613310   NaN     A
# 2314     2613312   NaN     B
# 2316     2616097   NaN     B
#
# [1377 rows x 3 columns]

# %%
df = df1.fillna('NA')
df
# Out:
#       Student ID 100-1 120-1
# 8        2306884    NA     B
# 10       2335068    NA     A
# 11       2340351    NA     A
# 12       2343598    NA     C
# 14       2373631    NA     A
# ...          ...   ...   ...
# 2309     2612061    NA     A
# 2311     2612309    NA     A
# 2313     2613310    NA     A
# 2314     2613312    NA     B
# 2316     2616097    NA     B
#
# [1377 rows x 3 columns]

# %% [markdown]
# ---
#
#
# **CHI-SQUARE TEST**
#
# Chi-square test finds the probability of a Null hypothesis(H0).
#
# **Assumption(H0): The two columns are NOT related to each other**
#
# Result of Chi-Sq Test: The Probability of H0 being True
#
# It can help to understand whether both the categorical variables are correlated with each other or not.

# %% [markdown]
# The Chi-square test of independence determines if there is a significant relationship between two categorical (i.e. nominal or ordinal) (with two or more mutually exclusive groups) variables. Hence, the null hypothesis is that no relationship exists between the two variables.

# %%
CrosstabResult=pd.crosstab(index=df['100-1'],columns=df['120-1'])
print(CrosstabResult)
 
# importing the required function
from scipy.stats import chi2_contingency
 
# Performing Chi-sq test
ChiSqResult = chi2_contingency(CrosstabResult)
 
# P-Value is the Probability of H0 being True
# If P-Value < 0.05 then we Accept the assumption(H0)

print('\nThe chi-square statistic of the ChiSq Test is:', ChiSqResult[0])
print('\nThe P-Value of the ChiSq Test is:', ChiSqResult[1])
print('\nThe DOF of the ChiSq Test is:', ChiSqResult[2])
print('\nThe expected contingency table of the ChiSq Test is:\n\n', ChiSqResult[3])
# Out:
# 120-1    A    B    C   D   F  I  U   W
# 100-1
# A       40   10    2   1   0  0  0   2
# B       17   14    7   3   8  0  0   0
# C        4    4    5   2   7  0  0   3
# D        0    2    0   0   2  0  0   1
# NA     675  262  133  39  98  1  2  31
# U        0    1    0   0   0  0  0   0
# W        0    0    0   0   1  0  0   0
#
# The chi-square statistic of the ChiSq Test is: 84.53521526049829
#
# The P-Value of the ChiSq Test is: 0.00010985280690225083
#
# The DOF of the ChiSq Test is: 42
#
# The expected contingency table of the ChiSq Test is:
#
#  [[2.93972404e+01 1.17029775e+01 5.87145969e+00 1.79738562e+00
#   4.63326071e+00 3.99419027e-02 7.98838054e-02 1.47785040e+00]
#  [2.61902687e+01 1.04262890e+01 5.23093682e+00 1.60130719e+00
#   4.12781409e+00 3.55846042e-02 7.11692084e-02 1.31663036e+00]
#  [1.33623820e+01 5.31953522e+00 2.66884532e+00 8.16993464e-01
#   2.10602760e+00 1.81554103e-02 3.63108206e-02 6.71750182e-01]
# ...

# %% [markdown]
# For the chi-squared test: the p-value is much less than 0.05 so we will accept the null hypothesis (H0), the 2 columns are not related to each other.

# %% [markdown]
# ---
#
#
# **CHANGING THE CATEGORICAL DATA TO NUMERICAL DATA**
#
# Such that for both EGR 100 and EGR 120:
#
# A = 9
#
# B = 8
#
# C = 7
#
# D = 6
#
# F = 5
#
# W = 4
#
# U = 3
#
# I = 2
#
# NA = 0

# %%
df1.loc[df1["100-1"] == "A", "100-1"] = 9
df1.loc[df1["100-1"] == "B", "100-1"] = 8
df1.loc[df1["100-1"] == "C", "100-1"] = 7
df1.loc[df1["100-1"] == "D", "100-1"] = 6
df1.loc[df1["100-1"] == "F", "100-1"] = 5
df1.loc[df1["100-1"] == "W", "100-1"] = 4
df1.loc[df1["100-1"] == "U", "100-1"] = 3
df1.loc[df1["100-1"] == "I", "100-1"] = 2
df1.loc[df1["100-1"] == "NA", "100-1"] = 0
df1
# Out:
#       Student ID 100-1 120-1
# 8        2306884   NaN     B
# 10       2335068   NaN     A
# 11       2340351   NaN     A
# 12       2343598   NaN     C
# 14       2373631   NaN     A
# ...          ...   ...   ...
# 2309     2612061   NaN     A
# 2311     2612309   NaN     A
# 2313     2613310   NaN     A
# 2314     2613312   NaN     B
# 2316     2616097   NaN     B
#
# [1377 rows x 3 columns]

# %%
df1.loc[df1["120-1"] == "A", "120-1"] = 9
df1.loc[df1["120-1"] == "B", "120-1"] = 8
df1.loc[df1["120-1"] == "C", "120-1"] = 7
df1.loc[df1["120-1"] == "D", "120-1"] = 6
df1.loc[df1["120-1"] == "F", "120-1"] = 5
df1.loc[df1["120-1"] == "W", "120-1"] = 4
df1.loc[df1["120-1"] == "U", "120-1"] = 3
df1.loc[df1["120-1"] == "I", "120-1"] = 2
df1
# Out:
#       Student ID 100-1 120-1
# 8        2306884   NaN     8
# 10       2335068   NaN     9
# 11       2340351   NaN     9
# 12       2343598   NaN     7
# 14       2373631   NaN     9
# ...          ...   ...   ...
# 2309     2612061   NaN     9
# 2311     2612309   NaN     9
# 2313     2613310   NaN     9
# 2314     2613312   NaN     8
# 2316     2616097   NaN     8
#
# [1377 rows x 3 columns]

# %% [markdown]
# ---
#
#
# **COMPUTING THE T-TEST**
#
# Since the sample dataset included NaN, I had to get rid of them to perform the t-test. I was not getting good results for keeping the EGR 100 grades as 0 (denote for NA/NaN). The results were p-value = 0 & statistic = -92.

# %%
## Dropping all NaNs from Data (significantly reduced to 136)
df2=df1.dropna(axis=0)
df2
# Out:
#       Student ID 100-1 120-1
# 51       2458874     8     9
# 87       2480138     8     8
# 247      2508551     9     9
# 302      2515806     9     9
# 320      2521026     7     5
# ...          ...   ...   ...
# 1716     2583953     9     8
# 1730     2585263     7     5
# 1738     2585690     9     9
# 1744     2586143     9     9
# 1841     2593271     9     9
#
# [136 rows x 3 columns]

# %% [markdown]
# The paired samples t-test follows the null and alternative hypotheses:
#
# H0: It signifies that the mean 100 and 120 scores are equal/dependant
#
# HA: It signifies that the mean 100 and 120 scores are not equal/dependant

# %%
import scipy.stats as stats
egr100 = df2["100-1"]
egr120 = df2["120-1"]
# Paired (related) test
t,p = stats.ttest_rel(egr100, egr120)
# ttest_rel is 2-tailed, so half the resulting p-value to get a 1-tailed p-value
p1 = '%0.8f' % (p/2)
print("t-statistic:" + str(t))
print("p-value:" + str(p))
# Out:
# t-statistic:3.212027271815132
# p-value:0.0016479815639026119

# %%
stats.ttest_rel(egr100, egr120)
# Out:
# TtestResult(statistic=3.212027271815132, pvalue=0.0016479815639026119, df=135)

# %% [markdown]
# As the p-value comes out to be less than 0.05, we reject the null hypothesis. So, we have enough proof to claim that the true mean egr 120 score is different for students before and after doing egr 100.

# %% [markdown]
# ---
#
#
# **EFFECT SIZE**
#
#
# ---

# %% [markdown]
# **Pearson's Correlation Coefficient**
#
# The association between variables is often referred to as the “r family” of
# effect size methods.
#
# This name comes from perhaps the most common method for calculating the effect size called Pearson’s correlation coefficient, also called Pearson’s r.
#
# The Pearson’s correlation coefficient measures the degree of linear association between two real-valued variables. It is a unit-free effect size measure, that can be interpreted in a standard way, as follows:
#
# -1.0: Perfect negative relationship
#
# -0.7: Strong negative relationship
#
# -0.5: Moderate negative relationship
#
# -0.3: Weak negative relationship
#
# 0.0: No relationship
#
# 0.3: Weak positive relationship
#
# 0.5: Moderate positive relationship
#
# 0.7: Strong positive relationship
#
# 1.0: Perfect positive relationship
#
# The Pearson’s correlation coefficient can be calculated in Python using the pearsonr() SciPy function.
#
# The example below demonstrates the calculation of the Pearson’s correlation coefficient to quantify the size of the association between two samples of EFD data where one sample has a strong relationship with the second.

# %%
from scipy.stats import pearsonr
# calculate Pearson's correlation
corr, _ = pearsonr(egr100, egr120)
print('Pearsons correlation: %.3f' % corr)
# Out:
# Pearsons correlation: 0.463

# %% [markdown]
# If we were to round up, there is a Moderate positive relationship between EGR 100 & EGR 120 grades.

# %% [markdown]
# ---
#
# **Difference Effect Size/ Cohen's d Effect Size**
#
# The difference between groups is often referred to as the “d family” of effect size methods.
#
# This name comes from perhaps the most common method for calculating the difference between the mean value of groups, called Cohen’s d.
#
# Cohen’s d measures the difference between the mean from two Gaussian-distributed variables. It is a standard score that summarizes the difference in terms of the number of standard deviations. Because the score is standardized, there is a table for the interpretation of the result, summarized as:
#
# Small Effect Size: d=0.20
#
# Medium Effect Size: d=0.50
#
# Large Effect Size: d=0.80
#
# The calculation of the difference between the mean of two samples is as follows:

# %%
# calculate the Cohen's d between two samples
from numpy import mean
from numpy import var
from math import sqrt
 
# function to calculate Cohen's d for independent samples
def cohend(d1, d2):
 # calculate the size of samples
 n1, n2 = len(d1), len(d2)
 # calculate the variance of the samples
 s1, s2 = var(d1, ddof=1), var(d2, ddof=1)
 # calculate the pooled standard deviation
 s = sqrt(((n1 - 1) * s1 + (n2 - 1) * s2) / (n1 + n2 - 2))
 # calculate the means of the samples
 u1, u2 = mean(d1), mean(d2)
 # calculate the effect size
 return (u1 - u2) / s
 
# prepare data
data1 = egr100
data2 = egr120
# calculate cohen's d
d = cohend(data1, data2)
print('Cohens d: %.3f' % d)
# Out:
# Cohens d: 0.297

# %% [markdown]
# ---
#
# **LOGISTIC REGRESSION**
#
#
#
# ---

# %%
df2['100-1']. value_counts(normalize = True)
# Out:
# 9    0.404412
# 8    0.360294
# 7    0.183824
# 6    0.036765
# 4    0.007353
# 3    0.007353
# Name: 100-1, dtype: float64

# %%
# Split data to be used in the models
# Create matrix of features
X = df2.drop(columns = ['120-1','Student ID'], axis = 1) 
#Create target variable
y = df2['120-1']
y = y.astype('int')

# %%
X
# Out:
#      100-1
# 51       8
# 87       8
# 247      9
# 302      9
# 320      7
# ...    ...
# 1716     9
# 1730     7
# 1738     9
# 1744     9
# 1841     9
#
# [136 rows x 1 columns]

# %%
y
# Out:
# 51      9
# 87      8
# 247     9
# 302     9
# 320     5
#        ..
# 1716    8
# 1730    5
# 1738    9
# 1744    9
# 1841    9
# Name: 120-1, Length: 136, dtype: int64

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1)

# %%
from sklearn.linear_model import LinearRegression

clf = LinearRegression().fit(X_train, y_train)
lin_pred = clf.predict(X_test)
lin_pred
# Out:
# array([7.61317216, 7.61317216, 3.16444352, 7.61317216, 7.61317216,
#        8.50291788, 8.50291788, 7.61317216, 8.50291788, 8.50291788,
#        6.72342643, 7.61317216, 6.72342643, 7.61317216, 6.72342643,
#        7.61317216, 8.50291788, 8.50291788, 7.61317216, 5.8336807 ,
#        7.61317216, 7.61317216, 7.61317216, 7.61317216, 6.72342643,
#        7.61317216, 8.50291788, 6.72342643, 8.50291788, 7.61317216,
#        7.61317216, 6.72342643, 8.50291788, 8.50291788])

# %%
len(y_train)
# Out:
# 102

# %%
plt.scatter(X_train,y_train)
plt.plot(X_test,lin_pred, "r-")
plt.show()
